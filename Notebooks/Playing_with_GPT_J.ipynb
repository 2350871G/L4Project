# %% [markdown]
# # Playing with GPT-J

# %%
# !pip install transformers
from transformers import GPTJForCausalLM
 
import torch

model = GPTJForCausalLM.from_pretrained("EleutherAI/gpt-j-6B", revision="float16", torch_dtype=torch.float16, low_cpu_mem_usage=True)
# Out:
# Requirement already satisfied: transformers in d:\lewis\anaconda\lib\site-packages (4.11.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in d:\lewis\anaconda\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in d:\lewis\anaconda\lib\site-packages (from transformers) (4.50.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\lewis\anaconda\lib\site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: packaging>=20.0 in d:\lewis\anaconda\lib\site-packages (from transformers) (20.4)
# Requirement already satisfied: pyyaml>=5.1 in d:\lewis\anaconda\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: sacremoses in d:\lewis\anaconda\lib\site-packages (from transformers) (0.0.46)
# Requirement already satisfied: huggingface-hub>=0.0.17 in d:\lewis\anaconda\lib\site-packages (from transformers) (0.0.19)
# Requirement already satisfied: numpy>=1.17 in d:\lewis\anaconda\lib\site-packages (from transformers) (1.19.2)
# Requirement already satisfied: filelock in d:\lewis\anaconda\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in d:\lewis\anaconda\lib\site-packages (from transformers) (2.24.0)
# Requirement already satisfied: six in d:\lewis\anaconda\lib\site-packages (from packaging>=20.0->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\lewis\anaconda\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: click in d:\lewis\anaconda\lib\site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in d:\lewis\anaconda\lib\site-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: typing-extensions in d:\lewis\anaconda\lib\site-packages (from huggingface-hub>=0.0.17->transformers) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\lewis\anaconda\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\lewis\anaconda\lib\site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in d:\lewis\anaconda\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\lewis\anaconda\lib\site-packages (from requests->transformers) (1.25.11)
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=836.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=12106053103.0), HTML(value='')))
# [Errno 28] No space left on device
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\Lewis\Anaconda\lib\site-packages\transformers\file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1665
# -> 1666             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1667
#
# D:\Lewis\Anaconda\lib\site-packages\transformers\file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1527             progress.update(len(chunk))
# -> 1528             temp_file.write(chunk)
#    1529     progress.close()
#
# D:\Lewis\Anaconda\lib\tempfile.py in func_wrapper(*args, **kwargs)
#     473             def func_wrapper(*args, **kwargs):
# --> 474                 return func(*args, **kwargs)
#     475             # Avoid closing the file as long as the wrapper is alive,
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# D:\Lewis\Anaconda\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1296                 # Load from URL or cache if already cached
# -> 1297                 resolved_archive_file = cached_path(
#    1298                     archive_file,
#
# D:\Lewis\Anaconda\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1401         # URL, so get it from the cache (downloading if necessary)
# -> 1402         output_path = get_from_cache(
#    1403             url_or_filename,
#
# D:\Lewis\Anaconda\lib\site-packages\transformers\file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1665
# -> 1666             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1667
#
# D:\Lewis\Anaconda\lib\tempfile.py in __exit__(self, exc, value, tb)
#     491     def __exit__(self, exc, value, tb):
# --> 492         result = self.file.__exit__(exc, value, tb)
#     493         self.close()
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-2a7aa03cf598> in <module>
#       4 import torch
#       5
# ----> 6 model = GPTJForCausalLM.from_pretrained("EleutherAI/gpt-j-6B", revision="float16", torch_dtype=torch.float16, low_cpu_mem_usage=True)
#
# D:\Lewis\Anaconda\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1316                     msg += f"- or '{revision}' is a valid git identifier (branch name, a tag name, or a commit id) that exists for this model name as listed on its model page on 'https://huggingface.co/models'\n\n"
#    1317
# -> 1318                 raise EnvironmentError(msg)
#    1319
#    1320             if resolved_archive_file == archive_file:
#
# OSError: Can't load weights for 'EleutherAI/gpt-j-6B'. Make sure that:
#
# - 'EleutherAI/gpt-j-6B' is a correct model identifier listed on 'https://huggingface.co/models'
#
# - or 'EleutherAI/gpt-j-6B' is the correct path to a directory containing a file named one of pytorch_model.bin, tf_model.h5, model.ckpt
#
# - or 'float16' is a valid git identifier (branch name, a tag name, or a commit id) that exists for this model name as listed on its model page on 'https://huggingface.co/models'

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")

prompt = ''''''

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

gen_tokens = model.generate(input_ids, do_sample=True, temperature=0.9, max_length=100,)
gen_text = tokenizer.batch_decode(gen_tokens)[0]

print(gen_text)
